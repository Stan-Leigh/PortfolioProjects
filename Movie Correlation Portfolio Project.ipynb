# %%
# Let's import the packages we will use in this project

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
# Read in the data and preview the first few rows

df = pd.read_csv('movies.csv')

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Check for missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %% [markdown]
# * Total entries is 7668. It can be observed that most of the columns have missing data. The budget column is the column with the most missing data.

# %% [markdown]
# ## Data Cleaning

# %%
# Drop rows with missing values

df.dropna(inplace=True)

# %%
# Convert column datatypes to the appropriate type

df = df.astype({'budget': 'int64', 'gross': 'int64', 'votes': 'int64'})
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create correct release year column

df['correctyear'] = df['released'].str.extract(pat='([0-9]{4})').astype(int)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Sort by budget in descending order

df.sort_values('budget', ascending=False).head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score   votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %%
# Sort by gross in descending order

df.sort_values('gross', ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %% [markdown]
# ## Finding Correlations in the Data

# %%
# Scatter plot of Budget vs Gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross earnings')

plt.xlabel('Budget for movie')
plt.ylabel('Gross Earnings')

plt.show()

# %% [markdown]
# * Hard to tell if they are correlated. Let's use a regplot to confirm.

# %%
# Regplot Budget vs Gross

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'blue'}, line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %% [markdown]
# * This regplot shows that gross and budget are positively correlated.

# %%
# Looking at the correlation for the different numerical columns

df.corr(method='pearson') 
# Different methods can be applied here. pearson is the default, but there's kendall and spearman methods too.
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# correctyear  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              correctyear
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# correctyear     1.000000

# %%
df.corr(method='kendall')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score        0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes        0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget       0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross        0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime      0.064824  0.292254  0.205344  0.231278  0.176979  1.000000
# correctyear  0.991304  0.043400  0.293044  0.213719  0.232372  0.064793
#
#              correctyear
# year            0.991304
# score           0.043400
# votes           0.293044
# budget          0.213719
# gross           0.232372
# runtime         0.064793
# correctyear     1.000000

# %%
df.corr('spearman')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score        0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes        0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget       0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross        0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime      0.095444  0.412155  0.300621  0.330794  0.257400  1.000000
# correctyear  0.998694  0.063674  0.422988  0.302535  0.340529  0.095507
#
#              correctyear
# year            0.998694
# score           0.063674
# votes           0.422988
# budget          0.302535
# gross           0.340529
# runtime         0.095507
# correctyear     1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='Blues')

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %% [markdown]
# * The darker the shade of blue, the more correlated those two features are

# %%
df_numeric = df.copy()

for colname in df_numeric.columns:
    if df_numeric[colname].dtype == 'object':
        df_numeric[colname] = df_numeric[colname].astype('category')
        df_numeric[colname] = df_numeric[colname].cat.codes

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numeric.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000       757    1818
# 3   204       4      4  1980      1127    7.7   221000       889    1413
# 4   732       6      4  1980      1170    7.3   108000       719     351
#
#    star  country    budget      gross  company  runtime  correctyear
# 0   699       46  19000000   46998772     1426    146.0         1980
# 1   214       47   4500000   58853106      452    104.0         1980
# 2  1157       47  18000000  538375067      945    124.0         1980
# 3  1474       47   3500000   83453539     1108     88.0         1980
# 4   271       47   6000000   39846344     1083     98.0         1980

# %%
df_numeric.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_matrix = df_numeric.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='vlag')

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# To unstack the correlation matrix i.e. look at the correlation for a column compared to the other columns
correlation_mat = df_numeric.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              correctyear    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
# Sort the pairing by the correlation value to easily see the most positive and negative correlated

sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
# budget       rating        -0.203946
# rating       gross         -0.181906
# gross        rating        -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# company      rating        -0.092357
# rating       company       -0.092357
# country      correctyear   -0.073569
# correctyear  country       -0.073569
# year         genre         -0.073167
# genre        year          -0.073167
#              company       -0.071334
# company      genre         -0.071334
# genre        correctyear   -0.069147
# correctyear  genre         -0.069147
# year         country       -0.066748
# country      year          -0.066748
# genre        runtime       -0.059237
# runtime      genre         -0.059237
# score        country       -0.043051
# ...

# %%
# Finding features with high correlation

high_corr = sorted_pairs[ (abs(sorted_pairs) > 0.5) & (sorted_pairs < 1.0) ]

high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# year         correctyear    0.998726
# correctyear  year           0.998726
# dtype: float64

# %% [markdown]
# * Votes and Budget have the highest correlation to Gross earnings

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64

# %%
# Total gross for each rating

RatingGrossSum = df.groupby('rating')[["gross"]].sum()

RatingGrossSumSorted = RatingGrossSum.sort_values('gross', ascending = False)

RatingGrossSumSorted = RatingGrossSumSorted['gross'].astype('int64') 

RatingGrossSumSorted
# Out:
# rating
# PG-13        266542294450
# R            145199814244
# PG           124929793534
# G             21006223173
# Not Rated       944428241
# TV-MA           700083289
# NC-17           191307081
# Unrated          40255080
# Approved         36565280
# X                17186348
# Name: gross, dtype: int64

# %%
sns.stripplot(x="rating", y="gross", data=df)

plt.title("Gross revenue for each rating")

plt.show()
